# %% [markdown]
# <a href="https://colab.research.google.com/github/poolaNaveen/Python/blob/main/pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.DataFrame([[1,2,3,4],[5,6,7,8]], columns=['a','b','c','d'])
df
# Out:
#    a  b  c  d
# 0  1  2  3  4
# 1  5  6  7  8

# %%
df.shape
# Out:
# (2, 4)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
df.columns
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df.values
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
##Dictionary of lists
data1 = {
    "id":[1,2,3],
    "name":["naveen","raju","pavan"],
    "score":[90,89,99]
}
df1=pd.DataFrame(data1)
df1
# Out:
#    id    name  score
# 0   1  naveen     90
# 1   2    raju     89
# 2   3   pavan     99

# %%
import pandas as pd
data7 = {
    "id":pd.Series([1,2,3]),
    "name":pd.Series(['naveen','kanna','ravi']),
    "score":pd.Series((90,87,67))

}
df2=pd.DataFrame(data7)
print(df2)
# Out:
#    id    name  score
# 0   1  naveen     90
# 1   2   kanna     87
# 2   3    ravi     67

# %%
import numpy as np
df1=pd.DataFrame(np.random.randint(0,10,(5,5)),columns='p1 p2 p3 p4 p5'.split(),index='a b c d e'.split() )
df1
# Out:
#    p1  p2  p3  p4  p5
# a   1   1   1   6   5
# b   1   0   5   2   6
# c   3   4   4   3   9
# d   4   8   0   1   8
# e   2   9   6   1   1

# %%
import pandas as pd

df=pd.read_csv("/content/retail_store_data.csv", encoding='latin')
df.head()
# Out:
#   Transaction_ID   Product       Category  Quantity  Price_per_Unit  \
# 0          T0001      Rice      Beverages         6             430
# 1          T0002      Soap  Personal Care         7             138
# 2          T0003      Rice         Snacks         4             497
# 3          T0004       Tea      Beverages         3             148
# 4          T0005  Biscuits      Beverages         4             340
#
#    Total_Sales Payment_Method  Customer_Age Store_Location  \
# 0         2580           Cash            46         Mumbai
# 1          966           Cash            45      Hyderabad
# 2         1988            UPI            49      Hyderabad
# 3          444            UPI            61      Bangalore
# 4         1360            UPI            59          Delhi
#
#                   Date
# 0  2023-01-01 00:00:00
# 1  2023-01-02 00:00:00
# 2  2023-01-03 00:00:00
# 3  2023-01-04 00:00:00
# 4  2023-01-05 00:00:00

# %%
df.shape
# Out:
# (100, 10)

# %%
df.columns
# Out:
# Index(['Transaction_ID', 'Product', 'Category', 'Quantity', 'Price_per_Unit',
#        'Total_Sales', 'Payment_Method', 'Customer_Age', 'Store_Location',
#        'Date'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
df['Product'].head()
# Out:
# 0        Rice
# 1        Soap
# 2        Rice
# 3         Tea
# 4    Biscuits
# Name: Product, dtype: object

# %%
df.head(2)
# Out:
#   Transaction_ID Product       Category  Quantity  Price_per_Unit  \
# 0          T0001    Rice      Beverages         6             430
# 1          T0002    Soap  Personal Care         7             138
#
#    Total_Sales Payment_Method  Customer_Age Store_Location  \
# 0         2580           Cash            46         Mumbai
# 1          966           Cash            45      Hyderabad
#
#                   Date
# 0  2023-01-01 00:00:00
# 1  2023-01-02 00:00:00

# %%
df.tail(2)
# Out:
#    Transaction_ID   Product Category  Quantity  Price_per_Unit  Total_Sales  \
# 98          T0099      Rice  Grocery         7              50          350
# 99          T0100  Biscuits  Grocery         6             298         1788
#
#    Payment_Method  Customer_Age Store_Location                 Date
# 98            UPI            59          Delhi  2023-04-09 00:00:00
# 99     Debit Card            46          Delhi  2023-04-10 00:00:00

# %%
print(df.iloc[[0, 2], [0, 2]])
# Out:
#   Transaction_ID   Category
# 0          T0001  Beverages
# 2          T0003     Snacks

# %%
KeyError
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3830273871.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df=pd.read_csv("/content/retail_store_data.csv", encoding='latin')
#       3 df.head()
#       4 pd.crosstab(df['Product'],df['City'])
#
# ...
